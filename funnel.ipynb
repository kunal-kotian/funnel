# %%
# %matplotlib inline 

import numpy as np
import matplotlib.pyplot as plt

# %%
def UserSim(n, parameter):
    """
    input :
    n, the number to of users to simulate
    parameter, the rate parameter (lambda)
    
    output: A list of exponential random variable simulations
    """
    return np.random.exponential(1/parameter,n) #1st parameter is scale = 1/parameter given aka lambda

# %% [markdown]
# 1(a)

# %%
n = 1000
parameter = 2
time_duration = UserSim(n,parameter)

# %%
np.histogram(time_duration, bins=8)
# Out:
# (array([   0,    0,    0,    0, 1000,    0,    0,    0]),
#  array([-0.5  , -0.375, -0.25 , -0.125,  0.   ,  0.125,  0.25 ,  0.375,
#          0.5  ]))

# %%
fig, ax = plt.subplots(1,1)
plt.hist(time_duration, rwidth=0.8,align='left')

plt.xlabel('Time')
plt.ylabel('Number of Users')
plt.title('Funnel Simulation')
plt.grid(False)

plt.show()

# %% [markdown]
# 1(b)

# %%
# generate exp rv with the respect of each lambda value
step = .2
start = .2
end = 3 + start
parameters = np.arange(start, end, step)
time_with_different_para = [UserSim(n,parameter) for parameter in parameters]

# %%
# plot for each alpha 
for i in range(len(parameters)):
    data = time_with_different_para[i]
    fig, ax = plt.subplots(1,1)
    plt.hist(data, rwidth=0.75,align='left',bins = np.arange(0,20,1))
    
    plt.xlim([0,20])
    plt.xticks(np.arange(0,20,1))
    plt.xlabel('Time')
    plt.ylabel('Number of Users')
    plt.title('Funnel Simulation with lambda = {:.2f}'.format(parameters[i]))
    plt.show()

# %% [markdown]
# 1(c)

# %% [markdown]
# Lambda and survival times has an inverse relationship. As lambda increases, survivial times decreases.

# %% [markdown]
# 2
